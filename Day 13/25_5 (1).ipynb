# %%
import pandas as pd
df = pd.read_excel('/content/Student new.xlsx')

# %%
df
# Out:
#        Name  Roll_No  Age
# 0  Karishma        1   19
# 1     Pooja        2   18
# 2      Riya        3   20
# 3    Sanjay        4   18

# %%
df.insert(3,"Gender",["Female","Female","Female","Male"])
print(df)
# Out:
#        Name  Roll_No  Age  Gender
# 0  Karishma        1   19  Female
# 1     Pooja        2   18  Female
# 2      Riya        3   20  Female
# 3    Sanjay        4   18    Male

# %%
df.loc[len(df)] = ["Immanuel", 6 , 20,"Male"]
print(df)
# Out:
#        Name  Roll_No  Age  Gender
# 0  Karishma        1   19  Female
# 1     Pooja        2   18  Female
# 2    Roshan        5   20    Male
# 3    Sanjay        4   18    Male
# 4    Roshan        5   20    Male
# 5  Immanuel        6   20    Male

# %%
df.drop('Age', axis = 1)
# Out:
#        Name  Roll_No  Gender
# 0  Karishma        1  Female
# 1     Pooja        2  Female
# 2    Roshan        5    Male
# 3    Sanjay        4    Male
# 4    Roshan        5    Male
# 5  Immanuel        6    Male

# %%
df.drop(df.index[2])
# Out:
#        Name  Roll_No  Age  Gender
# 0  Karishma        1   19  Female
# 1     Pooja        2   18  Female
# 3    Sanjay        4   18    Male
# 4    Roshan        5   20    Male
# 5  Immanuel        6   20    Male

# %%
print(df.replace(18,21))
# Out:
#        Name  Roll_No  Age  Gender
# 0  Karishma        1   19  Female
# 1     Pooja        2   21  Female
# 2    Roshan        5   20    Male
# 3    Sanjay        4   21    Male
# 4    Roshan        5   20    Male
# 5  Immanuel        6   20    Male

# %%
df["Name"] = df["Name"].str.lower()
print(df)
# Out:
#        Name  Roll_No  Age  Gender      Name
# 0  karishma        1   19  Female  karishma
# 1     pooja        2   18  Female     pooja
# 2    roshan        5   20    Male    roshan
# 3    sanjay        4   18    Male    sanjay
# 4    roshan        5   20    Male    roshan
# 5  immanuel        6   20    Male  immanuel
