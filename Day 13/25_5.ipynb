# %%
import pandas as pd
df = pd.read_excel('/content/Pass-Fail Data.xlsx')

# %%
df
# Out:
#     Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# 0            1                  95                   92             88
# 1            2                  88                   85             79
# 2            3                  60                   55             58
# 3            4                  72                   70             65
# 4            5                  40                   45             50
# ..         ...                 ...                  ...            ...
# 95          96                  89                   92             94
# 96          97                  79                   77             75
# 97          98                  55                   56             58
# 98          99                  91                   90             88
# 99         100                  52                   50             53
#
#     Study_hrs_per_week  Pass
# 0                   12     1
# 1                   10     1
# ...

# %%
print(df.head())
# Out:
#    Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# 0           1                  95                   92             88
# 1           2                  88                   85             79
# 2           3                  60                   55             58
# 3           4                  72                   70             65
# 4           5                  40                   45             50
#
#    Study_hrs_per_week  Pass
# 0                  12     1
# 1                  10     1
# 2                   4     0
# 3                   6     1
# 4                   3     0

# %%
print(df.tail())
# Out:
#     Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# 95          96                  89                   92             94
# 96          97                  79                   77             75
# 97          98                  55                   56             58
# 98          99                  91                   90             88
# 99         100                  52                   50             53
#
#     Study_hrs_per_week  Pass
# 95                  14     1
# 96                   8     1
# 97                   5     0
# 98                  12     1
# 99                   4     0

# %%
print(df.shape)
# Out:
# (100, 6)

# %%
print(df.columns)
# Out:
# Index(['Student_id', 'Attendance_percent', 'Homework_percentage',
#        'Midterm_score', 'Study_hrs_per_week', 'Pass'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Student_id           100 non-null    int64
#  1   Attendance_percent   100 non-null    int64
#  2   Homework_percentage  100 non-null    int64
#  3   Midterm_score        100 non-null    int64
#  4   Study_hrs_per_week   100 non-null    int64
#  5   Pass                 100 non-null    int64
# dtypes: int64(6)
# memory usage: 4.8 KB
# None

# %%
print(df.describe())
# Out:
#        Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# count  100.000000          100.000000            100.00000     100.000000
# mean    50.500000           69.520000             69.03000      68.780000
# std     29.011492           17.651783             17.01304      14.717254
# min      1.000000           30.000000             35.00000      42.000000
# 25%     25.750000           55.000000             55.00000      56.000000
# 50%     50.500000           72.500000             70.00000      68.000000
# 75%     75.250000           85.000000             85.00000      82.000000
# max    100.000000           95.000000             96.00000      97.000000
#
#        Study_hrs_per_week        Pass
# count           100.00000  100.000000
# mean              7.28000    0.600000
# std               3.62115    0.492366
# min               2.00000    0.000000
# 25%               4.00000    0.000000
# 50%               7.00000    1.000000
# ...

# %%
print("\nAfter Removing Duplicates:")
print(df.drop_duplicates())
# Out:
# After Removing Duplicates:
#     Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# 0            1                  95                   92             88
# 1            2                  88                   85             79
# 2            3                  60                   55             58
# 3            4                  72                   70             65
# 4            5                  40                   45             50
# ..         ...                 ...                  ...            ...
# 95          96                  89                   92             94
# 96          97                  79                   77             75
# 97          98                  55                   56             58
# 98          99                  91                   90             88
# 99         100                  52                   50             53
#
#     Study_hrs_per_week  Pass
# 0                   12     1
# ...

# %%
print(df['Student_id'].mean())
# Out:
# 50.5

# %%
print(df.sort_values(by='Attendance_percent'))
# Out:
#     Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# 10          11                  30                   35             42
# 40          41                  33                   38             45
# 70          71                  34                   39             44
# 22          23                  35                   40             48
# 52          53                  36                   41             47
# ..         ...                 ...                  ...            ...
# 60          61                  92                   91             89
# 90          91                  93                   92             90
# 44          45                  93                   94             95
# 74          75                  94                   96             97
# 0            1                  95                   92             88
#
#     Study_hrs_per_week  Pass
# 10                   2     0
# 40                   2     0
# ...

# %%
print(df.isnull())
# Out:
#     Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# 0        False               False                False          False
# 1        False               False                False          False
# 2        False               False                False          False
# 3        False               False                False          False
# 4        False               False                False          False
# ..         ...                 ...                  ...            ...
# 95       False               False                False          False
# 96       False               False                False          False
# 97       False               False                False          False
# 98       False               False                False          False
# 99       False               False                False          False
#
#     Study_hrs_per_week   Pass
# 0                False  False
# 1                False  False
# ...

# %%
print(df.notnull())
# Out:
#     Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# 0         True                True                 True           True
# 1         True                True                 True           True
# 2         True                True                 True           True
# 3         True                True                 True           True
# 4         True                True                 True           True
# ..         ...                 ...                  ...            ...
# 95        True                True                 True           True
# 96        True                True                 True           True
# 97        True                True                 True           True
# 98        True                True                 True           True
# 99        True                True                 True           True
#
#     Study_hrs_per_week  Pass
# 0                 True  True
# 1                 True  True
# ...

# %%
print(df.replace(12,11))
# Out:
#     Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# 0            1                  95                   92             88
# 1            2                  88                   85             79
# 2            3                  60                   55             58
# 3            4                  72                   70             65
# 4            5                  40                   45             50
# ..         ...                 ...                  ...            ...
# 95          96                  89                   92             94
# 96          97                  79                   77             75
# 97          98                  55                   56             58
# 98          99                  91                   90             88
# 99         100                  52                   50             53
#
#     Study_hrs_per_week  Pass
# 0                   11     1
# 1                   10     1
# ...

# %%
print(df.duplicated())
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 95    False
# 96    False
# 97    False
# 98    False
# 99    False
# Length: 100, dtype: bool

# %%
print(df.sample())
# Out:
#     Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# 94          95                  41                   43             48
#
#     Study_hrs_per_week  Pass
# 94                   3     0

# %%
print(df.rename(columns = {"Midterm_score" : "Midterm_Marks"}))
# Out:
#     Student_id  Attendance_percent  Homework_percentage  Midterm_Marks  \
# 0            1                  95                   92             88
# 1            2                  88                   85             79
# 2            3                  60                   55             58
# 3            4                  72                   70             65
# 4            5                  40                   45             50
# ..         ...                 ...                  ...            ...
# 95          96                  89                   92             94
# 96          97                  79                   77             75
# 97          98                  55                   56             58
# 98          99                  91                   90             88
# 99         100                  52                   50             53
#
#     Study_hrs_per_week  Pass
# 0                   12     1
# 1                   10     1
# ...

# %%
print(df["Student_id"].sum())
# Out:
# 5050

# %%
print(df["Student_id"].min())
# Out:
# 1

# %%
print(df["Student_id"].count())
# Out:
# 100

# %%
print(df["Student_id"].var())
# Out:
# 841.6666666666666

# %%
print(df["Student_id"].median())
# Out:
# 50.5

# %%
a = df.copy()
print(a)
# Out:
#     Student_id  Attendance_percent  Homework_percentage  Midterm_score  \
# 0            1                  95                   92             88
# 1            2                  88                   85             79
# 2            3                  60                   55             58
# 3            4                  72                   70             65
# 4            5                  40                   45             50
# ..         ...                 ...                  ...            ...
# 95          96                  89                   92             94
# 96          97                  79                   77             75
# 97          98                  55                   56             58
# 98          99                  91                   90             88
# 99         100                  52                   50             53
#
#     Study_hrs_per_week  Pass
# 0                   12     1
# 1                   10     1
# ...

# %%
import pandas as pd

data = {
    "Date": ["2026-05-20", "2026-05-21", "2026-05-22"]
}

df = pd.DataFrame(data)

df["Date"] = pd.to_datetime(df["Date"])

print(df)
# Out:
#         Date
# 0 2026-05-20
# 1 2026-05-21
# 2 2026-05-22

# %%
import pandas as pd

data = {
    "Grade": ["A", "B", "C", "A"]
}

df = pd.DataFrame(data)

result = df["Grade"].map({
    "A": "Excellent",
    "B": "Good",
    "C": "Average"
})

print(result)
# Out:
# 0    Excellent
# 1         Good
# 2      Average
# 3    Excellent
# Name: Grade, dtype: object

# %%
print(df.describe())
# Out:
#        Grade
# count      4
# unique     3
# top        A
# freq       2

# %%
print(df.dtypes)
# Out:
# Grade    object
# dtype: object
